# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Datasets/datos_2004.csv', encoding='latin1')
df
# Out:
#           FECHA CLAVE_EST PARAMETRO   HORA01   HORA02   HORA03   HORA04  \
# 0      01/01/04       AGU        CO    1.900    2.700    2.600    2.800
# 1      01/01/04       AGU       MHC   -0.010   -0.010   -0.010   -0.010
# 2      01/01/04       AGU       NO2    0.068    0.079    0.079    0.077
# 3      01/01/04       AGU       NOX    0.087    0.118    0.112    0.137
# 4      01/01/04       AGU        O3    0.017    0.010    0.009    0.009
# 5      01/01/04       AGU      PM10   87.200  124.800   94.800   66.000
# 6      01/01/04       AGU        RH   56.500   59.000   61.200   61.600
# 7      01/01/04       AGU       SO2    0.012    0.014    0.016    0.019
# 8      01/01/04       AGU       THC   -0.010   -0.020   -0.010   -0.010
# 9      01/01/04       AGU       TMP   16.700   16.100   15.900   15.800
# 10     01/01/04       AGU       WDR  169.000   10.000  348.000   71.000
# 11     01/01/04       AGU       WSP    1.387    1.642    2.734    2.204
# ...

# %%
df['avg'] = df[['HORA01','HORA02','HORA03']].mean(axis=1)
df.iloc[3]['PARAMETRO']
# Out:
# 'NOX'

# %%
df
# Out:
#           FECHA CLAVE_EST PARAMETRO   HORA01   HORA02   HORA03   HORA04  \
# 0      01/01/04       AGU        CO    1.900    2.700    2.600    2.800
# 1      01/01/04       AGU       MHC   -0.010   -0.010   -0.010   -0.010
# 2      01/01/04       AGU       NO2    0.068    0.079    0.079    0.077
# 3      01/01/04       AGU       NOX    0.087    0.118    0.112    0.137
# 4      01/01/04       AGU        O3    0.017    0.010    0.009    0.009
# 5      01/01/04       AGU      PM10   87.200  124.800   94.800   66.000
# 6      01/01/04       AGU        RH   56.500   59.000   61.200   61.600
# 7      01/01/04       AGU       SO2    0.012    0.014    0.016    0.019
# 8      01/01/04       AGU       THC   -0.010   -0.020   -0.010   -0.010
# 9      01/01/04       AGU       TMP   16.700   16.100   15.900   15.800
# 10     01/01/04       AGU       WDR  169.000   10.000  348.000   71.000
# 11     01/01/04       AGU       WSP    1.387    1.642    2.734    2.204
# ...

# %%
a = {}
for i in range(len(df)):
    if df.iloc[i]['PARAMETRO'] == 'CO':
         a.append(df.iloc[i][['HORA01','HORA02','HORA03']].mean())
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f814e649dd2f> in <module>()
#       2 for i in range(len(df)):
#       3     if df.iloc[i]['PARAMETRO'] == 'CO':
# ----> 4          a.append(df.iloc[i][['HORA01','HORA02','HORA03']].mean())
#       5 a
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
df

# %%
df.head()
