# %%
import pandas
import statistics
import numpy as np

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
vehiculos = pd.read_csv("datos.csv")

# %%
autos = pd.Series(vehiculos.Automoviles).str.replace(",","").astype(int)#estaban en string y los cambia a int
autos
# Out:
# 0      202910
# 1      218395
# 2      255167
# 3      284383
# 4      318898
# 5      331669
# 6      343961
# 7      358600
# 8      375829
# 9      400895
# 10     426235
# 11     468857
# 12     491922
# 13     596290
# 14     638157
# 15     608765
# 16     570580
# 17     641904
# 18     659648
# 19     652389
# 20     730603
# 21     783455
# 22     946458
# 23    1014350
# 24    1081386
# 25    1148872
# 26    1266511
# 27    1383889
# 28    1508483
# 29    1554138
# 30    1615356
# 31    1680336
# 32    1701489
# 33    1721050
# 34    1814989
# 35    1908689
# 36    2012979
# 37    2115230
# Name: Automoviles, dtype: int64

# %%
vehiculos
# Out:
#     Year      Total Automoviles Camiones para pasajeros  \
# 0   1980    347,483     202,910                   4,402
# 1   1981    386,231     218,395                   4,807
# 2   1982    404,645     255,167                   5,043
# 3   1983    438,343     284,383                   5,348
# 4   1984    487,847     318,898                   5,955
# 5   1985    508,494     331,669                   6,167
# 6   1986    530,801     343,961                   6,358
# 7   1987    555,905     358,600                   6,542
# 8   1988    586,990     375,829                   6,536
# 9   1989    627,739     400,895                   6,823
# 10  1990    674,854     426,235                   6,922
# 11  1991    741,520     468,857                   7,613
# 12  1992    789,194     491,922                   7,199
# 13  1993  1,006,337     596,290                   6,564
# 14  1994  1,067,022     638,157                   6,438
# 15  1995  1,020,996     608,765                   8,316
# 16  1996  1,016,481     570,580                   7,866
# 17  1997  1,077,616     641,904                   6,739
# 18  1998  1,099,757     659,648                   6,616
# 19  1999  1,114,421     652,389                   7,671
# 20  2000  1,303,109     730,603                   8,543
# 21  2001  1,376,637     783,455                   8,706
# 22  2002  1,681,096     946,458                  10,073
# 23  2003  1,814,156   1,014,350                  11,653
# 24  2004  1,940,129   1,081,386                  10,996
# 25  2005  2,066,373   1,148,872                  10,566
# 26  2006  2,207,186   1,266,511                  10,353
# 27  2007  2,381,424   1,383,889                  10,554
# 28  2008  2,592,027   1,508,483                  10,971
# 29  2009  2,659,712   1,554,138                  10,795
# 30  2010  2,754,043   1,615,356                  11,071
# 31  2011  2,861,984   1,680,336                  11,159
# 32  2012  2,902,432   1,701,489                  10,735
# 33  2013  2,953,747   1,721,050                  10,860
# 34  2014  3,112,643   1,814,989                  11,191
# 35  2015  3,268,321   1,908,689                  11,468
# 36  2016  3,429,847   2,012,979                  11,538
# 37  2017  3,605,557   2,115,230                  11,576
#
#    Camiones y camionetas para carga Motocicletas  Unnamed: 6
# 0                           114,260       25,911         NaN
# 1                           128,636       34,393         NaN
# 2                           126,684       17,751         NaN
# 3                           135,724       12,888         NaN
# 4                           151,333       11,661         NaN
# 5                           158,377       12,281         NaN
# 6                           167,096       13,386         NaN
# 7                           177,069       13,694         NaN
# 8                           190,691       13,934         NaN
# 9                           205,688       14,333         NaN
# 10                          225,412       16,285         NaN
# 11                          247,951       17,099         NaN
# 12                          267,601       22,472         NaN
# 13                          394,018        9,465         NaN
# 14                          399,424       23,003         NaN
# 15                          390,095       13,820         NaN
# 16                          396,474       41,561         NaN
# 17                          386,164       42,809         NaN
# 18                          388,115       45,378         NaN
# 19                          409,242       45,119         NaN
# 20                          511,440       52,523         NaN
# 21                          567,996       16,480         NaN
# 22                          660,328       64,237         NaN
# 23                          713,582       74,571         NaN
# 24                          761,760       85,987         NaN
# 25                          805,628      101,307         NaN
# 26                          816,171      114,151         NaN
# 27                          856,577      130,404         NaN
# 28                          921,433      151,140         NaN
# 29                          932,715      162,064         NaN
# 30                          949,163      178,453         NaN
# 31                          968,947      201,542         NaN
# 32                          967,812      222,396         NaN
# 33                          980,672      241,165         NaN
# 34                        1,006,006      280,457         NaN
# 35                        1,026,596      321,568         NaN
# 36                        1,043,027      362,303         NaN
# 37                        1,062,735      416,016         NaN

# %%
plt.plot(vehiculos.Year, autos, "o" )
plt.xlabel("Años")
plt.ylabel("Autos")
plt.show()

# %%
autos.mean() #Promedio de autos por año
# Out:
# 916676.7631578947

# %%
autos_lista = [] #agrega los datos de lo carros a una lista
for i in autos:
    autos_lista.append(i)
print(autos_lista)
# Out:
# [202910, 218395, 255167, 284383, 318898, 331669, 343961, 358600, 375829, 400895, 426235, 468857, 491922, 596290, 638157, 608765, 570580, 641904, 659648, 652389, 730603, 783455, 946458, 1014350, 1081386, 1148872, 1266511, 1383889, 1508483, 1554138, 1615356, 1680336, 1701489, 1721050, 1814989, 1908689, 2012979, 2115230]

# %%
aumento_por_año = [] #Resta de aumento de carros por año
for i in range(len(autos_lista)-1):
    aumento_por_año.append(autos_lista[i+1] - autos_lista[i])
print(aumento_por_año)
# Out:
# [15485, 36772, 29216, 34515, 12771, 12292, 14639, 17229, 25066, 25340, 42622, 23065, 104368, 41867, -29392, -38185, 71324, 17744, -7259, 78214, 52852, 163003, 67892, 67036, 67486, 117639, 117378, 124594, 45655, 61218, 64980, 21153, 19561, 93939, 93700, 104290, 102251]

# %%
print(sum(aumento_por_año)/len(aumento_por_año)) #Promedio de aumento por año
# Out:
# 51684.32432432433

# %%
plt.plot(vehiculos.Year[1:], aumento_por_año)
plt.xlabel("Años")
plt.ylabel("Aumento de carros por año")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
regr = linear_model.LinearRegression()
regr.fit(vehiculos.Year, autos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-437a163d0eab> in <module>()
#       1 regr = linear_model.LinearRegression()
# ----> 2 regr.fit(vehiculos.Year, autos)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993
#  1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014 2015 2016 2017].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
import seaborn as sns

# %%
sns.jointplot(x=vehiculos[, y=autos, kind='reg')
